# %%
import pandas as pd
import numpy as np
import seaborn as sns
from google.colab import files
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.decomposition import PCA
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.regularizers import l2
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping

# %%
import os

# Daftar file perusahaan
file_paths = [
    "/content/BBCA_FINAL.xlsx",
    "/content/BBNI_FINAL.xlsx",
    "/content/BBRI_FINAL.xlsx",
    "/content/BBTN_FINAL.xlsx",
    "/content/BMRI_FINAL.xlsx"
]

# Thresholds for movement classification
thresholds = [1, 2, 3]

# Dictionary untuk menyimpan hasil evaluasi
all_results = {}

for file_path in file_paths:
    company_name = os.path.basename(file_path).split("_")[0]  # Nama perusahaan dari file
    print(f"Processing {company_name}...")

    # Baca file Excel ke dalam DataFrame
    data = pd.read_excel(file_path)

    # Hitung persentase perubahan dan bersihkan data
    data['pct_change'] = data['Close'].pct_change() * 100
    data.dropna(inplace=True)

    # Distribusi pergerakan berdasarkan threshold
    movement_distributions = {}
    for threshold in thresholds:
        data[f'movement_{threshold}'] = data['pct_change'].apply(
            lambda x: 1 if x > threshold else (-1 if x < -threshold else 0)
        )
        movement_distributions[threshold] = data[f'movement_{threshold}'].value_counts().reindex([1, 0, -1], fill_value=0)

        # Visualisasi distribusi
        colors = ['blue', 'green', 'red']
        movement_counts = movement_distributions[threshold]
        x_labels = ['1 (Up)', '0 (Stagnant)', '-1 (Down)']

        plt.figure(figsize=(6, 4))
        plt.bar(x_labels, movement_counts.values, color=colors)
        plt.title(f'Distribution of Movement for {company_name} (Threshold = {threshold}%)')
        plt.xlabel('Movement Classes')
        plt.ylabel('Count')
        plt.grid(axis='y', linestyle='--', alpha=0.7)
        plt.show()

    # Memilih threshold terbaik
    best_threshold = 2

    # Persiapan data untuk model
    X = data[['pct_change', 'ROA']].values
    y = data[f'movement_{best_threshold}'].values

    split_idx = int(0.8 * len(X))
    X_train, X_test = X[:split_idx], X[split_idx:]
    y_train, y_test = y[:split_idx], y[split_idx:]

    y_one_hot_train = to_categorical(y_train + 1, num_classes=3)
    y_one_hot_test = to_categorical(y_test + 1, num_classes=3)

    # Normalisasi data
    scaler = MinMaxScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)

    # Model Neural Network
    model = Sequential([
        Dense(64, activation='relu', input_shape=(X_train.shape[1],), kernel_regularizer=l2(0.01)),
        Dropout(0.3),
        Dense(32, activation='relu', kernel_regularizer=l2(0.01)),
        Dropout(0.3),
        Dense(3, activation='softmax')
    ])

    model.compile(
        loss='binary_crossentropy',
        optimizer='adam',
        metrics=['accuracy']
    )

    # Early stopping
    early_stopping = EarlyStopping(
        monitor='val_loss',
        patience=10,
        restore_best_weights=True
    )

    # Training model
    history = model.fit(
        X_train, y_one_hot_train,
        epochs=50,
        batch_size=16,
        validation_data=(X_test, y_one_hot_test),
        verbose=1,
        callbacks=[early_stopping]
    )

    # Prediksi dan evaluasi
    y_train_pred_prob = model.predict(X_train)
    y_train_pred = np.argmax(y_train_pred_prob, axis=1) - 1
    y_test_pred_prob = model.predict(X_test)
    y_test_pred = np.argmax(y_test_pred_prob, axis=1) - 1

    conf_matrix_train = confusion_matrix(y_train, y_train_pred, labels=[-1, 0, 1])
    conf_matrix_test = confusion_matrix(y_test, y_test_pred, labels=[-1, 0, 1])

    fig, axes = plt.subplots(2, 1, figsize=(6, 10))

    disp_train = ConfusionMatrixDisplay(confusion_matrix=conf_matrix_train, display_labels=['-1 (Down)', '0 (Stagnant)', '1 (Up)'])
    disp_train.plot(cmap='Blues', ax=axes[0], colorbar=True)
    axes[0].set_title(f"Confusion Matrix - Training Data ({company_name})")

    disp_test = ConfusionMatrixDisplay(confusion_matrix=conf_matrix_test, display_labels=['-1 (Down)', '0 (Stagnant)', '1 (Up)'])
    disp_test.plot(cmap='Blues', ax=axes[1], colorbar=True)
    axes[1].set_title(f"Confusion Matrix - Testing Data ({company_name})")

    plt.tight_layout()
    plt.show()

    # Evaluasi performa
    train_accuracy = accuracy_score(y_train, y_train_pred)
    test_accuracy = accuracy_score(y_test, y_test_pred)
    train_f1_score = f1_score(y_train, y_train_pred, average='weighted')
    test_f1_score = f1_score(y_test, y_test_pred, average='weighted')
    train_precision = precision_score(y_train, y_train_pred, average='weighted')
    test_precision = precision_score(y_test, y_test_pred, average='weighted')
    train_recall = recall_score(y_train, y_train_pred, average='weighted')
    test_recall = recall_score(y_test, y_test_pred, average='weighted')

    evaluation_results = pd.DataFrame({
        'Metric': ['Accuracy', 'F1 Score', 'Precision', 'Recall'],
        'Training': [train_accuracy, train_f1_score, train_precision, train_recall],
        'Testing': [test_accuracy, test_f1_score, test_precision, test_recall]
    })

    print(f"Evaluation Results for {company_name}:")
    print(evaluation_results.to_string(index=False))
    all_results[company_name] = evaluation_results
# Out:
# Processing BBCA...
# Epoch 1/50
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5541 - loss: 1.1059 - val_accuracy: 0.6538 - val_loss: 0.9148
# Epoch 2/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5728 - loss: 0.9029 - val_accuracy: 0.6538 - val_loss: 0.7611
# Epoch 3/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5828 - loss: 0.7740 - val_accuracy: 0.6538 - val_loss: 0.6756
# Epoch 4/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5758 - loss: 0.6995 - val_accuracy: 0.6538 - val_loss: 0.6263
# Epoch 5/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5759 - loss: 0.6628 - val_accuracy: 0.6538 - val_loss: 0.5953
# Epoch 6/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5396 - loss: 0.6459 - val_accuracy: 0.6538 - val_loss: 0.5741
# Epoch 7/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5840 - loss: 0.6023 - val_accuracy: 0.6538 - val_loss: 0.5620
# Epoch 8/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5567 - loss: 0.6118 - val_accuracy: 0.6538 - val_loss: 0.5530
# Epoch 9/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5600 - loss: 0.6006 - val_accuracy: 0.6538 - val_loss: 0.5478
# Epoch 10/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5316 - loss: 0.6017 - val_accuracy: 0.6538 - val_loss: 0.5447
# Epoch 11/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5482 - loss: 0.5938 - val_accuracy: 0.6538 - val_loss: 0.5410
# Epoch 12/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5425 - loss: 0.5938 - val_accuracy: 0.6538 - val_loss: 0.5394
# Epoch 13/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5681 - loss: 0.5822 - val_accuracy: 0.6538 - val_loss: 0.5386
# Epoch 14/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5763 - loss: 0.5840 - val_accuracy: 0.6538 - val_loss: 0.5362
# Epoch 15/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5564 - loss: 0.5850 - val_accuracy: 0.6538 - val_loss: 0.5372
# Epoch 16/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5702 - loss: 0.5804 - val_accuracy: 0.6538 - val_loss: 0.5352
# Epoch 17/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5513 - loss: 0.5853 - val_accuracy: 0.6538 - val_loss: 0.5338
# Epoch 18/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5222 - loss: 0.6039 - val_accuracy: 0.6538 - val_loss: 0.5334
# Epoch 19/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5570 - loss: 0.5819 - val_accuracy: 0.6538 - val_loss: 0.5319
# Epoch 20/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5474 - loss: 0.5841 - val_accuracy: 0.6538 - val_loss: 0.5315
# Epoch 21/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5714 - loss: 0.5787 - val_accuracy: 0.6538 - val_loss: 0.5331
# Epoch 22/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5828 - loss: 0.5680 - val_accuracy: 0.6538 - val_loss: 0.5336
# Epoch 23/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5976 - loss: 0.5617 - val_accuracy: 0.6538 - val_loss: 0.5326
# Epoch 24/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.
# Epoch 34/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4026 - loss: 0.6319 - val_accuracy: 0.5256 - val_loss: 0.6042
# Epoch 35/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4068 - loss: 0.6315 - val_accuracy: 0.5256 - val_loss: 0.6051
# Epoch 36/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4182 - loss: 0.6340 - val_accuracy: 0.5256 - val_loss: 0.6048
# Epoch 37/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3919 - loss: 0.6340 - val_accuracy: 0.5256 - val_loss: 0.6035
# Epoch 38/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4170 - loss: 0.6302 - val_accuracy: 0.5256 - val_loss: 0.6050
# Epoch 39/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4187 - loss: 0.6301 - val_accuracy: 0.5256 - val_loss: 0.6039
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Evaluation Results for BMRI:
#    Metric  Training  Testing
#  Accuracy  0.421474 0.525641
#  F1 Score  0.249939 0.362206
# Precision  0.177641 0.276298
#    Recall  0.421474 0.525641
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
import os

# Daftar file perusahaan
file_paths = [
    "/content/ANTM_FINAL.xlsx",
    "/content/INCO_FINAL.xlsx",
    "/content/INKP_FINAL.xlsx",
    "/content/INTP_FINAL.xlsx",
    "/content/SMGR_FINAL.xlsx"
]

# Thresholds for movement classification
thresholds = [1, 2, 3]

# Dictionary untuk menyimpan hasil evaluasi
all_results = {}

for file_path in file_paths:
    company_name = os.path.basename(file_path).split("_")[0]  # Nama perusahaan dari file
    print(f"Processing {company_name}...")

    # Baca file Excel ke dalam DataFrame
    data = pd.read_excel(file_path)

    # Hitung persentase perubahan dan bersihkan data
    data['pct_change'] = data['Close'].pct_change() * 100
    data.dropna(inplace=True)

    # Distribusi pergerakan berdasarkan threshold
    movement_distributions = {}
    for threshold in thresholds:
        data[f'movement_{threshold}'] = data['pct_change'].apply(
            lambda x: 1 if x > threshold else (-1 if x < -threshold else 0)
        )
        movement_distributions[threshold] = data[f'movement_{threshold}'].value_counts().reindex([1, 0, -1], fill_value=0)

        # Visualisasi distribusi
        colors = ['blue', 'green', 'red']
        movement_counts = movement_distributions[threshold]
        x_labels = ['1 (Up)', '0 (Stagnant)', '-1 (Down)']

        plt.figure(figsize=(6, 4))
        plt.bar(x_labels, movement_counts.values, color=colors)
        plt.title(f'Distribution of Movement for {company_name} (Threshold = {threshold}%)')
        plt.xlabel('Movement Classes')
        plt.ylabel('Count')
        plt.grid(axis='y', linestyle='--', alpha=0.7)
        plt.show()

    # Memilih threshold terbaik
    best_threshold = 2

    # Persiapan data untuk model
    X = data[['pct_change', 'ROA']].values
    y = data[f'movement_{best_threshold}'].values

    split_idx = int(0.8 * len(X))
    X_train, X_test = X[:split_idx], X[split_idx:]
    y_train, y_test = y[:split_idx], y[split_idx:]

    y_one_hot_train = to_categorical(y_train + 1, num_classes=3)
    y_one_hot_test = to_categorical(y_test + 1, num_classes=3)

    # Normalisasi data
    scaler = MinMaxScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)

    # Model Neural Network
    model = Sequential([
        Dense(64, activation='relu', input_shape=(X_train.shape[1],), kernel_regularizer=l2(0.01)),
        Dropout(0.3),
        Dense(32, activation='relu', kernel_regularizer=l2(0.01)),
        Dropout(0.3),
        Dense(3, activation='softmax')
    ])

    model.compile(
        loss='binary_crossentropy',
        optimizer='adam',
        metrics=['accuracy']
    )

    # Early stopping
    early_stopping = EarlyStopping(
        monitor='val_loss',
        patience=10,
        restore_best_weights=True
    )

    # Training model
    history = model.fit(
        X_train, y_one_hot_train,
        epochs=50,
        batch_size=16,
        validation_data=(X_test, y_one_hot_test),
        verbose=1,
        callbacks=[early_stopping]
    )

    # Prediksi dan evaluasi
    y_train_pred_prob = model.predict(X_train)
    y_train_pred = np.argmax(y_train_pred_prob, axis=1) - 1
    y_test_pred_prob = model.predict(X_test)
    y_test_pred = np.argmax(y_test_pred_prob, axis=1) - 1

    conf_matrix_train = confusion_matrix(y_train, y_train_pred, labels=[-1, 0, 1])
    conf_matrix_test = confusion_matrix(y_test, y_test_pred, labels=[-1, 0, 1])

    fig, axes = plt.subplots(2, 1, figsize=(6, 10))

    disp_train = ConfusionMatrixDisplay(confusion_matrix=conf_matrix_train, display_labels=['-1 (Down)', '0 (Stagnant)', '1 (Up)'])
    disp_train.plot(cmap='Blues', ax=axes[0], colorbar=True)
    axes[0].set_title(f"Confusion Matrix - Training Data ({company_name})")

    disp_test = ConfusionMatrixDisplay(confusion_matrix=conf_matrix_test, display_labels=['-1 (Down)', '0 (Stagnant)', '1 (Up)'])
    disp_test.plot(cmap='Blues', ax=axes[1], colorbar=True)
    axes[1].set_title(f"Confusion Matrix - Testing Data ({company_name})")

    plt.tight_layout()
    plt.show()

    # Evaluasi performa
    train_accuracy = accuracy_score(y_train, y_train_pred)
    test_accuracy = accuracy_score(y_test, y_test_pred)
    train_f1_score = f1_score(y_train, y_train_pred, average='weighted')
    test_f1_score = f1_score(y_test, y_test_pred, average='weighted')
    train_precision = precision_score(y_train, y_train_pred, average='weighted')
    test_precision = precision_score(y_test, y_test_pred, average='weighted')
    train_recall = recall_score(y_train, y_train_pred, average='weighted')
    test_recall = recall_score(y_test, y_test_pred, average='weighted')

    evaluation_results = pd.DataFrame({
        'Metric': ['Accuracy', 'F1 Score', 'Precision', 'Recall'],
        'Training': [train_accuracy, train_f1_score, train_precision, train_recall],
        'Testing': [test_accuracy, test_f1_score, test_precision, test_recall]
    })

    print(f"Evaluation Results for {company_name}:")
    print(evaluation_results.to_string(index=False))
    all_results[company_name] = evaluation_results
# Out:
# Processing ANTM...
# Epoch 1/50
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.3810 - loss: 1.0871 - val_accuracy: 0.3718 - val_loss: 0.9484
# Epoch 2/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4614 - loss: 0.9070 - val_accuracy: 0.3718 - val_loss: 0.8277
# Epoch 3/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4600 - loss: 0.7941 - val_accuracy: 0.3718 - val_loss: 0.7573
# Epoch 4/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4363 - loss: 0.7370 - val_accuracy: 0.3718 - val_loss: 0.7152
# Epoch 5/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4439 - loss: 0.6953 - val_accuracy: 0.3718 - val_loss: 0.6886
# Epoch 6/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4219 - loss: 0.6700 - val_accuracy: 0.3718 - val_loss: 0.6721
# Epoch 7/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4384 - loss: 0.6507 - val_accuracy: 0.3718 - val_loss: 0.6632
# Epoch 8/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4202 - loss: 0.6494 - val_accuracy: 0.3718 - val_loss: 0.6565
# Epoch 9/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4542 - loss: 0.6368 - val_accuracy: 0.3718 - val_loss: 0.6514
# Epoch 10/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4478 - loss: 0.6344 - val_accuracy: 0.3718 - val_loss: 0.6479
# Epoch 11/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4556 - loss: 0.6310 - val_accuracy: 0.3718 - val_loss: 0.6475
# Epoch 12/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.